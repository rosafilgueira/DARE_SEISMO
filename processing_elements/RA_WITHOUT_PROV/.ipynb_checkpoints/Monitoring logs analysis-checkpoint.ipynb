# %%
import pandas as pd
import json

# %% [markdown]
# ## Plot the workflow

# %%
from IPython.display import Image
Image(filename='misfit.png')

# %%
df=pd.read_csv("monitor_misfit.csv")
df.head()
# Out:
#              PE  rank      method  \
# 0        data29     0        read
# 1        data29     0  preprocess
# 2        data29     0       write
# 3        data29     0       write
# 4  PE_detrend17     5        read
#
#                                                 data         start  \
# 0                                      {'input': []}  1.566490e+09
# 1                                                 {}  1.566490e+09
# 2  {'output': 'output_real', 'size': 1031, 'id': ...  1.566490e+09
# 3  {'output': 'output_synt', 'size': 1031, 'id': ...  1.566490e+09
# 4  {'input': [('input', ('data29', 0, 'output_rea...  1.566490e+09
#
#             end
# 0  1.566490e+09
# 1  1.566490e+09
# 2  1.566490e+09
# 3  1.566490e+09
# 4  1.566490e+09

# %% [markdown]
# ## Communication times

# %%
def communication_time(df):
    write_logs = df.loc[df['method'] == 'write'][['PE', 'rank', 'start', 'end', 'data']]
    wcols = write_logs['data'].apply(eval).map(lambda d: [d['id'], d['size']]).apply(pd.Series)
    write_logs['data_id'] = wcols[0]
    write_logs['data_size'] = wcols[1]
    write_logs = write_logs.drop(columns=['data'])
    
    read_logs = df.loc[df['method'] == 'read'][['PE', 'rank', 'start', 'end', 'data']]
    rcols = read_logs['data'].apply(eval).map(lambda d: d['input']).apply(pd.Series)
    read_logs['data_id'] = rcols[0].map(lambda t : t[1] if isinstance(t, tuple) else None)
    read_logs = read_logs[read_logs['data_id'].notnull()]
    read_logs = read_logs.drop(columns=['data'])
    
    jdf = read_logs.set_index('data_id').join(write_logs.set_index('data_id'), lsuffix='_r', rsuffix='_w')
    jdf['t_comm'] = jdf[['end_w', 'end_r']].max(axis=1) - jdf[['start_r', 'start_w']].max(axis=1)
    communication_times = jdf[['PE_w', 'rank_w', 'PE_r', 'rank_r', 't_comm']].sort_values(by=['t_comm'], ascending=False)
    ct = communication_times[['PE_w', 'PE_r', 't_comm']].groupby(['PE_w', 'PE_r']).mean()
    return ct

# %%
ct=communication_time(df) 
ct
# Out:
#                                              t_comm
# PE_w                 PE_r
# PE_detrend17         PE_taper18            0.014604
# PE_detrend23         PE_taper24            0.014602
# PE_filter_bandpass22 RotationPE30          0.013869
# PE_filter_bandpass28 RotationPE31          0.013182
# PE_filter_highpass21 PE_filter_bandpass22  0.014390
# PE_filter_highpass27 PE_filter_bandpass28  0.015048
# PE_filter_lowpass20  PE_filter_highpass21  0.014845
# PE_filter_lowpass26  PE_filter_highpass27  0.013278
# PE_pre_filter25      PE_filter_lowpass26   0.014026
# PE_remove_response19 PE_filter_lowpass20   0.013977
# PE_taper18           PE_remove_response19  0.015595
# PE_taper24           PE_pre_filter25       0.014960
# RotationPE30         StoreStream32         0.021335
# RotationPE31         StoreStream33         0.015132
# data29               PE_detrend17          0.016835
#                      PE_detrend23          0.019076

# %% [markdown]
# ## Processing times

# %% [markdown]
# Retrieve the processing times for each PE instance

# %%
def processing_times(df):
    pl = df.loc[df['method'] == 'process'][['PE', 'rank', 'start', 'end']]
    pl['t_proc'] = pl['end'] - pl['start']
    processing_times = pl.drop(columns=['start', 'end'])
    pt= processing_times[['PE', 't_proc']].groupby(['PE']).mean()
    return pt

# %%
pt=processing_times(df)
pt
# Out:
#                         t_proc
# PE
# PE_detrend17          0.007945
# PE_detrend23          0.014089
# PE_filter_bandpass22  0.006270
# PE_filter_bandpass28  0.005508
# PE_filter_highpass21  0.006580
# PE_filter_highpass27  0.004811
# PE_filter_lowpass20   0.004719
# PE_filter_lowpass26   0.004760
# PE_pre_filter25       0.001847
# PE_remove_response19  0.056481
# PE_taper18            0.001431
# PE_taper24            0.001405
# RotationPE30          0.001697
# RotationPE31          0.001553
# StoreStream32         0.005664
# StoreStream33         0.003139
# data29                6.659814

# %% [markdown]
# Calculate the average processing time for each PE

# %%
import matplotlib.pyplot as plt
pt.plot(kind='bar')
plt.show()

# %%
ct.plot(kind='bar')
plt.show()

# %%
from graphviz import Digraph
f = Digraph('misfit_times', filename='misfit_time.gv')
f.attr(size='20,20')
f.attr('node', shape='circle')

def node_name(x):
    name=x
    f.node(name, label='%s: \n%s' % (x, str(pt.loc[x][0])))

def edge_name(x):
    communication_time=str(ct.loc[x][0])
    f.edge(x[0], x[1], label= communication_time)
    

pt.index.map(lambda t: node_name(t))
f.attr('node', shape='circle')
ct.index.map(lambda t: edge_name(t))

f

# %%
f.render(filename='misfit_time', format="png")
# Out:
# 'misfit_time.png'

# %%
# !open misfit_time.png
